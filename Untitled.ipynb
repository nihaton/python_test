# %%
# データの読み込み
import pandas as pd
import codecs
in_path = 'e:/pywork/input/rent.csv'
in_file = codecs.open(in_path, 'r', encoding='shift-jis')
df = pd.read_csv(in_file)
in_file.close()
df = df.set_index('c1')
df.head()
# Out:
#     c2  c3  c4
# c1
# 1   82   3  42
# 2   12   3  34
# 3    2  13  54
# 4   52   3  14
# 5    2  23  94

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(df.T)
plt.show()

# 相関係数を表示
df.T.corr()
print(df.T.corr())
# Out:
# c:\users\administrator\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
# c1         1         2         3         4         5         6         7
# c1
# 1   1.000000  0.275151 -0.207852  0.955130 -0.224918  0.851043 -0.708628
# 2   0.275151  1.000000  0.883213 -0.021950  0.874881  0.738994  0.483368
# 3  -0.207852  0.883213  1.000000 -0.488245  0.999847  0.336737  0.837462
# 4   0.955130 -0.021950 -0.488245  1.000000 -0.503425  0.657329 -0.885817
# 5  -0.224918  0.874881  0.999847 -0.503425  1.000000  0.320227  0.846887
# 6   0.851043  0.738994  0.336737  0.657329  0.320227  1.000000 -0.232574
# 7  -0.708628  0.483368  0.837462 -0.885817  0.846887 -0.232574  1.000000

# %%
import statsmodels.formula.api as sm
reg = "y ~ x1 + x2"
model = sm.ols(formula=reg, data=df.T)

# 回帰分析を実行する
result = model.fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\users\administrator\appdata\local\programs\python\python36\lib\site-packages\patsy\compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35     try:
# ---> 36         return f(*args, **kwargs)
#      37     except Exception as e:
#
# c:\users\administrator\appdata\local\programs\python\python36\lib\site-packages\patsy\eval.py in eval(self, expr, source_name, inner_namespace)
#     165         return eval(code, {}, VarLookupDict([inner_namespace]
# --> 166                                             + self._namespaces))
#     167
#
# <string> in <module>
#
# NameError: name 'x1' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# <ipython-input-43-3cdb246d3855> in <module>
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from matplotlib import cm

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = y = np.arange(-15, 15, 0.5)
X, Y = np.meshgrid(x, y)

sigma = 4
Z = np.exp(-(X**2 + Y**2)/(2*sigma**2)) / (2*np.pi*sigma**2)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm)
plt.savefig("matplotlib_mplot3d_surface.png")

ax.clear()
ax.plot_wireframe(X, Y, Z, rstride=2, cstride=2)
plt.savefig("matplotlib_mplot3d_wireframe.png")

ax.clear()
ax.scatter(X, Y, Z, s=1)
plt.savefig("matplotlib_mplot3d_scatter.png")
